# %% [markdown]
# # Classifying Tumors in Mammograms
#
# # Part 1B MIAS Base CNN Modeling

# %% [markdown]
# ## Contents
# - [Overview](#Overview)
# - [Data Import & Cleaning](#Data-Import-&-Cleaning)
# - [Data Augmentation](#Data-Augmentation)
# - [CNN 1](#CNN-1)
# - [CNN 2](#CNN-2)
# - [CNN 3](#CNN-3)
# - [CNN 4](#CNN-4)
# - [Conclusions](#Conclusions)

# %% [markdown]
# ## Overview
#
# ### Modeling Techniques Explored
#
# - Resizing
# - Gray scaling of image
# - Reflection - flip images horizontally and vertically
# - Rotation - Form of upsampling your dataset since it creates rotated copies of the same image.
#
#
# ### Choice of Hyperparameters
# - Loss function - binary_crossentropy
# - Optimizer - Adam (Looking for a steady decrease in loss rate)
# - Metrics - Since we're dealing with life and death cancer diagnoses, False Negatives are far more detrimental since they mean you miss diiagnosing a tumor so reducing False Negatives is the aim. Also should pay attention to Accuracy and F1 score. Accuracy is important since we care how many True Positives our model finds but the F1 score is the harmonic mean of the model's Precision and Recall and is used when the False Negatives and False Positives might be more critical. In our classification problem, there is definitely imbalanced class distribution and thus F1-score might be a better metric to evaluate our model on.
# - Learning Rate / Epochs - Aimed for slower learning rates
# - The sigmoid function is used for the two-class logistic regression, whereas the softmax function is used for the multiclass logistic regression. In our case, we used the sigmoid for the tumor/no tumor classification. If we were to expand this project to tumor types we would need to use the softmax function.

# %% [markdown]
# ## Data Import & Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
import glob
from sklearn.preprocessing import LabelEncoder

# %%
tf.random.set_seed(1234)

# %%
images = []
labels = []
files = glob.glob('./data/all-mias/mdb*')

# %%
for file in files:
    image = cv2.imread(file,0)
    images.append(image)

# %%
#Check first image
for i in range(1):
    plt.imshow(images[i],cmap=plt.get_cmap('viridis'))
    plt.show()

# %%
# Check first 5 images with different filter
for i in range(5):
    plt.imshow(images[i],cmap=plt.get_cmap('bone'))
    plt.show()

# %%
images[0][512][512]
# Out:
# 130

# %%
# Import labels
labels = pd.read_csv('./data/Info_red.txt',delimiter=' ',names=['ID','bg','ab_type','diagnosis','ab_x','ab_y','ab_r'])

# %%
labels.head()
# Out:
#        ID bg ab_type diagnosis ab_x ab_y   ab_r
# 0  mdb001  G    CIRC         B  535  425  197.0
# 1  mdb002  G    CIRC         B  522  280   69.0
# 2  mdb003  D    NORM       NaN  NaN  NaN    NaN
# 3  mdb004  D    NORM       NaN  NaN  NaN    NaN
# 4  mdb005  F    CIRC         B  477  133   30.0

# %%
# Baseline

labels['diagnosis'].fillna('N',inplace=True)
labels['tumor'] = labels['diagnosis'].map(lambda x: 0 if x == 'N' else 1)
labels['tumor'].value_counts(normalize=True)
# Out:
# 0    0.627273
# 1    0.372727
# Name: tumor, dtype: float64

# %%
labels['ab_x'].fillna(512,inplace=True)
labels['ab_y'].fillna(512,inplace=True)
labels['ab_r'].fillna(0,inplace=True)

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         330 non-null    object
#  1   bg         330 non-null    object
#  2   ab_type    330 non-null    object
#  3   diagnosis  330 non-null    object
#  4   ab_x       330 non-null    object
#  5   ab_y       330 non-null    object
#  6   ab_r       330 non-null    float64
#  7   tumor      330 non-null    int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.8+ KB

# %%
labels['ID'] = labels['ID'].map(lambda x: x[3:])
labels['ID'].value_counts()
# Out:
# 226    3
# 249    2
# 144    2
# 223    2
# 239    2
#       ..
# 216    1
# 102    1
# 319    1
# 078    1
# 151    1
# Name: ID, Length: 322, dtype: int64

# %%
labels['ab_type'].value_counts(normalize = True)
# Out:
# NORM    0.627273
# CALC    0.090909
# CIRC    0.075758
# SPIC    0.057576
# ARCH    0.057576
# ASYM    0.045455
# MISC    0.045455
# Name: ab_type, dtype: float64

# %%
labels['bg'].value_counts(normalize = True)
# Out:
# D    0.354545
# F    0.330303
# G    0.315152
# Name: bg, dtype: float64

# %%
labels['diagnosis'].value_counts(normalize=True)
# Out:
# N    0.627273
# B    0.209091
# M    0.163636
# Name: diagnosis, dtype: float64

# %%
labels.columns
# Out:
# Index(['ID', 'bg', 'ab_type', 'diagnosis', 'ab_x', 'ab_y', 'ab_r', 'tumor'], dtype='object')

# %%
# Scale image data

images = [image/255 for image in images]

# %%
images = np.array(images)

# %%
tumor = np.array(labels['tumor'])

# %%
images.shape
# Out:
# (322, 1024, 1024)

# %%
labels.shape
# Out:
# (330, 8)

# %%
img_name = np.array(labels['ID'])

# %%
# img_name = []

# for i in range(len(labels['ID'])):
#         img_name.append(path + labels.ID[i]+ '.pgm')

# %% [markdown]
# ## Data Augmentation

# %%
# Rotating images - Train test split before augmenting!
# Tried changing rotations with different iterations
#Reference: https://www.kaggle.com/codeer/mias-mammography-cnn

X = list(range(len(files)))
y = list(range(len(files)))
train_i, test_i, dummy_train, dummy_test = train_test_split(X,y,random_state = 42)
img_path_train = []
last_label_train = []
img_path_test = []
last_label_test = []
IMG_SIZE = 180 
print(train_i)
for i in range(len(files)):
    
    img = cv2.imread(files[i], 0)
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
    rows, cols= img.shape
    for angle in range(180):
        if i in train_i:
            
            #M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle*2, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (IMG_SIZE, IMG_SIZE))
            img_path_train.append(img_rotated)
            if tumor[i] == 1:
                last_label_train.append(1)
            else:
                last_label_train.append(0)
        else:
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle*2, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (IMG_SIZE, IMG_SIZE))
            img_path_test.append(img_rotated)
            if tumor[i] == 1:
                last_label_test.append(1)
            else:
                last_label_test.append(0)
# Out:
# [168, 148, 221, 227, 139, 59, 163, 6, 198, 30, 22, 274, 247, 56, 167, 145, 206, 81, 147, 39, 222, 308, 183, 152, 140, 109, 66, 199, 18, 186, 153, 19, 223, 92, 79, 124, 184, 72, 96, 15, 111, 10, 182, 69, 97, 234, 68, 23, 37, 232, 67, 258, 238, 125, 286, 86, 272, 146, 285, 262, 237, 144, 210, 155, 260, 129, 38, 224, 193, 157, 112, 211, 117, 298, 310, 292, 177, 265, 154, 203, 2, 115, 165, 202, 120, 290, 279, 127, 74, 29, 83, 267, 107, 175, 181, 133, 219, 249, 297, 65, 228, 85, 246, 159, 12, 35, 28, 170, 142, 220, 131, 194, 51, 95, 239, 178, 254, 41, 89, 250, 136, 26, 315, 141, 231, 0, 289, 304, 306, 100, 192, 277, 213, 103, 171, 98, 36, 240, 61, 150, 47, 233, 266, 11, 318, 200, 288, 27, 301, 230, 4, 122, 32, 242, 162, 282, 275, 138, 62, 215, 135, 300, 128, 312, 8, 70, 284, 64, 44, 14, 156, 40, 295, 123, 296, 278, 216, 280, 236, 207, 212, 294, 251, 313, 201, 161, 43, 217, 190, 259, 105, 53, 1, 49, 80, 205, 34, 263, 91, 52, 264, 241, 13, 88, 273, 166, 316, 134, 309, 243, 54, 50, 174, 189, 320, 187, 169, 58, 48, 235, 252, 21, 160, 276, 191, 293, 257, 149, 130, 151, 99, 87, 214, 121, 321, 20, 188, 71, 106, 270, 102]

# %%
img_path_train = np.array(img_path_train)
last_label_train = np.array(last_label_train)
img_path_test = np.array(img_path_test)
last_label_test = np.array(last_label_test)
img_path_train.shape, img_path_test.shape
# Out:
# ((43380, 256, 256), (14580, 256, 256))

# %%
img_path_train = img_path_train.reshape((-1,IMG_SIZE,IMG_SIZE,1))
img_path_test = img_path_test.reshape((-1,IMG_SIZE,IMG_SIZE,1))
img_path_train.shape, img_path_test.shape
# Out:
# ((43380, 256, 256, 1), (14580, 256, 256, 1))

# %%
last_label_train.shape, last_label_test.shape
# Out:
# ((43380,), (14580,))

# %%
# Helper Function for checking out our train loss and test loss over epochs

def Loss_Acc_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize = (15,6))
    fig.suptitle("Model Metrics", fontsize = 25, fontweight = 'bold')
    fig.savefig('Accuracy_Loss_figure.png')

    ax1.plot(range(1, len(acc) + 1), acc,  color='#185fad')
    ax1.plot(range(1, len(val_acc) + 1), val_acc, color='orange')
    ax1.set_title('History of Accuracy by Epoch', fontsize=20)
    ax1.set_xlabel('Epoch', fontsize=18)
    ax1.set_ylabel('Accuracy', fontsize=18)
    ax1.legend(['training', 'validation'], fontsize=18)


    ax2.plot(range(1, len(loss) + 1), loss, color='#185fad')
    ax2.plot(range(1, len(val_loss) + 1), val_loss, color='orange')
    ax2.set_title('History of Loss by Epoch', fontsize=20)
    ax2.set_xlabel('Epoch', fontsize=18)
    ax2.set_ylabel('Binary Crossentropy (Loss)', fontsize=18)
    ax2.legend(['training', 'validation'], fontsize=18)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## CNN 1
# - 2 Convolutional and Pooling layers
# - Dropout, Early Stop
# - Full image resolution

# %%
X = np.expand_dims(images,axis=3)
y = labels.drop_duplicates(subset='ID')['tumor']
y.shape
# Out:
# (322,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 42, test_size=0.20)

# %%
X.shape, y.shape
# Out:
# ((322, 1024, 1024, 1), (322,))

# %%
# Instantiate a CNN.
rows, cols, color = X_train[0].shape
cnn = Sequential()

cnn.add(Conv2D(filters = 6,       #number of filters to use
              kernel_size = (3, 3),   #dimensions of the filters
              activation = 'relu',    #activation function
              input_shape = (1024,1024,1), #shape of image
              padding='valid', 
              #strides=(1, 1)
              ))  

cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(6, (3, 3), padding='valid', strides=(1, 1), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Dropout(0.25))
cnn.add(Flatten())
cnn.add(Dense(1, activation = 'sigmoid'))

cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 1022, 1022, 6)     60
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 511, 511, 6)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 509, 509, 6)       330
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 254, 254, 6)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 254, 254, 6)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 387096)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 387097
# =================================================================
# Total params: 387,487
# Trainable params: 387,487
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Commented out since I had rerun the whole notebook at one point

# # Compile model
# cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# early_stop = EarlyStopping(monitor = 'val_loss', 
#                            min_delta = 0,
#                            patience = 5, 
#                            verbose = 1, 
#                            mode='auto', 
#                            restore_best_weights=True)

# # Fit model on training data
# history_bw = cnn.fit(X_train, y_train, validation_data = (X_test, y_test),
#                  batch_size = 32,
#                  epochs = 1000,
#                  verbose = 1,
#                  callbacks=[early_stop],
#                  validation_split=0.2
# )

# %%
loss_value , accuracy = cnn.evaluate(X_test, y_test)
print('Test Loss = ' + str(loss_value))
print('Test Accuracy = ' + str(accuracy))
# Out:
# 3/3 [==============================] - 3s 711ms/step - loss: 0.6845 - accuracy: 0.6154
# Test Loss = 0.6844510436058044
# Test Accuracy = 0.6153846383094788

# %%
Loss_Acc_Plot(history_bw.history['accuracy'],history_bw.history['val_accuracy'],
               history_bw.history['loss'],history_bw.history['val_loss'])

# %%
preds = cnn.predict(X_test)
preds.shape
# Out:
# (65, 1)

# %% [markdown]
# ## CNN 2

# %%
# Compile model
cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor = 'val_loss', 
                           min_delta = 0,
                           patience = 5, 
                           verbose = 1, 
                           mode='auto', 
                           restore_best_weights=True)

# Fit model on training data
history_bw = cnn.fit(X_train, y_train, validation_data = (X_test, y_test),
                 batch_size = 32,
                 epochs = 1000,
                 verbose = 1,
                 callbacks=[early_stop],
                 validation_split=0.2
)
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 41s 5s/step - loss: 1.5497 - accuracy: 0.4780 - val_loss: 0.8155 - val_accuracy: 0.5577
# Epoch 2/1000
# 7/7 [==============================] - 45s 6s/step - loss: 0.8994 - accuracy: 0.6585 - val_loss: 0.6646 - val_accuracy: 0.6538
# Epoch 3/1000
# 7/7 [==============================] - 42s 6s/step - loss: 0.7594 - accuracy: 0.5073 - val_loss: 0.8203 - val_accuracy: 0.4038
# Epoch 4/1000
# 7/7 [==============================] - 44s 6s/step - loss: 0.6399 - accuracy: 0.6780 - val_loss: 1.0152 - val_accuracy: 0.5769
# Epoch 5/1000
# 7/7 [==============================] - 40s 6s/step - loss: 0.6378 - accuracy: 0.6780 - val_loss: 0.8635 - val_accuracy: 0.5769
# Epoch 6/1000
# 7/7 [==============================] - 41s 6s/step - loss: 0.6073 - accuracy: 0.6780 - val_loss: 0.7862 - val_accuracy: 0.5769
# Epoch 7/1000
# 7/7 [==============================] - 43s 6s/step - loss: 0.5898 - accuracy: 0.6732 - val_loss: 0.7855 - val_accuracy: 0.5769
# Restoring model weights from the end of the best epoch.
# Epoch 00007: early stopping

# %%
loss_value , accuracy = cnn.evaluate(X_test, y_test)
print('Test Loss = ' + str(loss_value))
print('Test Accuracy = ' + str(accuracy))
# Out:
# 3/3 [==============================] - 3s 818ms/step - loss: 0.7272 - accuracy: 0.5846
# Test Loss = 0.7271549701690674
# Test Accuracy = 0.5846154093742371

# %%
Loss_Acc_Plot(history_bw.history['accuracy'],history_bw.history['val_accuracy'],
               history_bw.history['loss'],history_bw.history['val_loss'])

# %% [markdown]
# ## CNN 3

# %%
X_train = np.array(img_path_train)
X_test = np.array(img_path_test)
y_train = np.array(last_label_train)
y_test = np.array(last_label_test)

# %%
X_train.shape, X_test.shape
# Out:
# ((43380, 128, 128, 1), (14580, 128, 128, 1))

# %%
# Instantiate a CNN.
cnn = Sequential()

cnn.add(Conv2D(filters = 32,       #number of filters to use
              kernel_size = (3, 3),   #dimensions of the filters
              activation = 'relu',    #activation function
              input_shape = (128,128,1), #shape of image
              #padding='valid', 
              #strides=(1, 1)
              ))  

cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(64, (3, 3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(64, (3, 3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

#cnn.add(Dropout(0.25))
cnn.add(Flatten())

cnn.add(Dense(96, activation = 'relu'))

cnn.add(Dense(1, activation = 'sigmoid'))

cnn.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_28 (Conv2D)           (None, 126, 126, 32)      320
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 96)                1204320
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 97
# =================================================================
# Total params: 1,260,161
# Trainable params: 1,260,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor = 'val_loss', 
                           min_delta = 0,
                           patience = 5, 
                           verbose = 1, 
                           mode='auto', 
                           restore_best_weights=True)

# Fit model on training data
history_bw = cnn.fit(X_train, y_train, validation_data = (X_test, y_test),
                 batch_size = 64,
                 epochs = 100,
                 verbose = 1,
                 callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 678/678 [==============================] - 319s 469ms/step - loss: 0.7431 - accuracy: 0.6482 - val_loss: 0.8588 - val_accuracy: 0.5363
# Epoch 2/100
# 678/678 [==============================] - 339s 500ms/step - loss: 0.4093 - accuracy: 0.8035 - val_loss: 1.6404 - val_accuracy: 0.5119
# Epoch 3/100
# 678/678 [==============================] - 332s 490ms/step - loss: 0.1783 - accuracy: 0.9280 - val_loss: 2.5262 - val_accuracy: 0.5073
# Epoch 4/100
# 678/678 [==============================] - 329s 486ms/step - loss: 0.0852 - accuracy: 0.9699 - val_loss: 3.7408 - val_accuracy: 0.4968
# Epoch 5/100
# 678/678 [==============================] - 341s 503ms/step - loss: 0.0565 - accuracy: 0.9813 - val_loss: 4.3953 - val_accuracy: 0.5115
# Epoch 6/100
# 678/678 [==============================] - 336s 495ms/step - loss: 0.0380 - accuracy: 0.9886 - val_loss: 4.4891 - val_accuracy: 0.5126
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping

# %%
loss_value , accuracy = cnn.evaluate(X_test, y_test)
print('Test Loss = ' + str(loss_value))
print('Test Accuracy = ' + str(accuracy))
# Out:
# 456/456 [==============================] - 24s 52ms/step - loss: 0.8588 - accuracy: 0.5363
# Test Loss = 0.8587608933448792
# Test Accuracy = 0.5362825989723206

# %%
Loss_Acc_Plot(history_bw.history['accuracy'],history_bw.history['val_accuracy'],
               history_bw.history['loss'],history_bw.history['val_loss'])

# %% [markdown]
# ## CNN 4

# %%
# Instantiate a CNN.
cnn = Sequential()

cnn.add(Conv2D(filters = 64,       #number of filters to use
              kernel_size = (3, 3),   #dimensions of the filters
              activation = 'relu',    #activation function
              input_shape = (128,128,1), #shape of image
              #padding='valid', 
              #strides=(1, 1)
              ))  

cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(64, (3, 3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(64, (3, 3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

#cnn.add(Dropout(0.25))
cnn.add(Flatten())

cnn.add(Dense(96, activation = 'relu'))
cnn.add(Dense(64, activation = 'relu'))
cnn.add(Dense(64, activation = 'relu'))

cnn.add(Dense(1, activation = 'sigmoid'))

cnn.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_43 (Conv2D)           (None, 126, 126, 64)      640
# _________________________________________________________________
# max_pooling2d_43 (MaxPooling (None, 63, 63, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 61, 61, 64)        36928
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 12544)             0
# _________________________________________________________________
# dense_30 (Dense)             (None, 96)                1204320
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                6208
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_33 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 1,289,249
# Trainable params: 1,289,249
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor = 'val_loss', 
                           min_delta = 0,
                           patience = 5, 
                           verbose = 1, 
                           mode='auto', 
                           restore_best_weights=True)

# Fit model on training data
history_bw = cnn.fit(X_train, y_train, validation_data = (X_test, y_test),
                 batch_size = 64,
                 epochs = 100,
                 verbose = 1,
                 callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 678/678 [==============================] - 545s 803ms/step - loss: 0.7129 - accuracy: 0.6413 - val_loss: 0.7776 - val_accuracy: 0.5398
# Epoch 2/100
# 678/678 [==============================] - 541s 798ms/step - loss: 0.4722 - accuracy: 0.7673 - val_loss: 1.3013 - val_accuracy: 0.5047
# Epoch 3/100
# 678/678 [==============================] - 541s 798ms/step - loss: 0.2777 - accuracy: 0.8777 - val_loss: 2.0135 - val_accuracy: 0.5152
# Epoch 4/100
# 678/678 [==============================] - 536s 791ms/step - loss: 0.1643 - accuracy: 0.9353 - val_loss: 2.8091 - val_accuracy: 0.5370
# Epoch 5/100
# 678/678 [==============================] - 730s 954ms/step - loss: 0.1061 - accuracy: 0.9604 - val_loss: 2.9315 - val_accuracy: 0.5010
# Epoch 6/100
# 678/678 [==============================] - 522s 771ms/step - loss: 0.0736 - accuracy: 0.9732 - val_loss: 3.5573 - val_accuracy: 0.5329
# Restoring model weights from the end of the best epoch.
# Epoch 00006: early stopping

# %%
loss_value , accuracy = cnn.evaluate(X_test, y_test)
print('Test Loss = ' + str(loss_value))
print('Test Accuracy = ' + str(accuracy))
# Out:
# 456/456 [==============================] - 48s 105ms/step - loss: 0.7776 - accuracy: 0.5398
# Test Loss = 0.777642011642456
# Test Accuracy = 0.5398491024971008

# %%
Loss_Acc_Plot(history_bw.history['accuracy'],history_bw.history['val_accuracy'],
               history_bw.history['loss'],history_bw.history['val_loss'])

# %% [markdown]
# ## CNN 5 - Didn't run

# %%
X_train = np.array(img_path_train)
X_test = np.array(img_path_test)
y_train = np.array(last_label_train)
y_test = np.array(last_label_test)

# %%
# Instantiate a CNN.
cnn = Sequential()

cnn.add(Conv2D(filters = 32,       #number of filters to use
              kernel_size = (3, 3),   #dimensions of the filters
              activation = 'relu',    #activation function
              input_shape = (256,256,1), #shape of image
              #padding='valid', 
              #strides=(1, 1)
              ))  

cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Conv2D(64, (3, 3), activation = 'relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))

cnn.add(Dropout(0.4))
cnn.add(Flatten())

cnn.add(Dense(32, activation = 'relu'))

cnn.add(Dense(1, activation = 'sigmoid'))

cnn.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_59 (Conv2D)           (None, 254, 254, 32)      320
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 125, 125, 64)      18496
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 62, 62, 64)        0
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 246016)            0
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                7872544
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 7,891,393
# Trainable params: 7,891,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Compile model
# cnn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# early_stop = EarlyStopping(monitor = 'val_loss', 
#                            min_delta = 0,
#                            patience = 2, 
#                            verbose = 1, 
#                            mode='auto', 
#                            restore_best_weights=True)

# # Fit model on training data
# history_bw = cnn.fit(X_train, y_train, validation_data = (X_test, y_test),
#                  batch_size = 64,
#                  epochs = 100,
#                  verbose = 1,
#                  callbacks=[early_stop]
# )

# %%
# Loss_Acc_Plot(history_bw.history['accuracy'],history_bw.history['val_accuracy'],
#                history_bw.history['loss'],history_bw.history['val_loss'])

# %% [markdown]
# ## Conclusions
#
# - Massively overfit models and performance is not much better than baseline 62.7%
# - Need more training data and to explore more image preprocessing and data augmentation methods
# - Be sure to Train test split before augmenting any images. When you rotate images it creates copies and if you split these after the fact you will most likely cause data leakage
